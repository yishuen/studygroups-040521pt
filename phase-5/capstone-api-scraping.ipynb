# %% [markdown]
# # Capstone Recap: APIs and Webscraping
#
# 1. Twint for tweets: https://pypi.org/project/twint/
# 2. Spotipy for Spotify data: https://spotipy.readthedocs.io/en/2.16.1/
# 3. PRAW for Reddit data
# 3. Scraping XML from BoardGameGeek
# 4. Scraping apartments from Craigslist

# %% [markdown]
# ## Twint

# %%
import twint
import pandas as pd

import nest_asyncio # for some reason, needed to excute the api call
nest_asyncio.apply()

# %%
c = twint.Config()

c.Search = "covid"
c.Min_likes = 100
c.Count = True
c.Limit = 100

c.Store_csv = True
c.Output = 'covidtweets.csv'

# %% [markdown]
# Twint Config attributes: https://github.com/twintproject/twint/wiki/Tweet-attributes

# %%
twint.run.Search(c)
# Out:
# 1438201669481902085 2021-09-15 14:02:53 -0400 <RonFilipkowski> The Trinidad &amp; Tobago Health Minister says there has been no reported cases of adverse side effects from the covid vaccine to the testicles of any person in their country. Thank you.   https://t.co/1fLN7t0etd
# 1438201015354941448 2021-09-15 14:00:17 -0400 <drfahrettinkoca> TURUNCU İLİMİZ KALMADI. Türkiye Covid-19 Risk Haritasında son Turuncu ilimiz Gümüşhane, ilk doz aşı oranını %65’in üzerine çıkararak Sarıya geçti. Şimdi sıra, Maviye geçecek başarıyı göstermekte. GÜMÜŞHANE’Yİ KUTLUYORUZ.
# 1438200348649435138 2021-09-15 13:57:38 -0400 <g1> Ministro da Saúde diz que há 'excesso de vacinas no Brasil'; seis estados estão com falta de imunizante para segunda dose  https://t.co/OYxXTqt7au #G1 #saúde #vacina #covid
# 1438200327090618375 2021-09-15 13:57:33 -0400 <tribelaw> 663,000 Americans have died of Covid-19 as of September 15, 2021. That’s 1 out of every 500 of us, or 20 out of every 10,000. We should’ve done better.
# 1438199702311391235 2021-09-15 13:55:04 -0400 <Reuters> Portugal fully vaccinates 80% of population against COVID-19  https://t.co/vDN8oDMFuz  https://t.co/DmnhQR95eh
# 1438199277772288008 2021-09-15 13:53:22 -0400 <CFCDUBois> 3 weeks without playing a game of football due to COVID but Giroud will still come off the bench and score at Anfield. Bookmark this, save this, screenshot this. First touch finish in the last 25 minutes.
# 1438199274169319436 2021-09-15 13:53:22 -0400 <CoronavirusBra1> União Europeia anuncia doação de mais 200 milhões de vacinas contra Covid para países de baixa renda até meados de 2022.
# 1438198195662753800 2021-09-15 13:49:04 -0400 <CoriBush> 1 in 500 Americans have died from COVID-19.  Deaths are surging across the country. 2,652 people died yesterday.  But pandemic relief — from unemployment benefits, to direct payments, to the eviction moratorium — have gone away.  The pandemic is not over. Bring back the relief.
# 1438197093118758913 2021-09-15 13:44:42 -0400 <rimbaudarth> Ahora que está mejorando la situación del Covid, no hay que perder de vista que el principal interesado en que no se deje de hablar de la pandemia es Sánchez, quien la ha utilizado para tapar, prácticamente desde que empezó la legislatura, todas sus tropelías y su inutilidad.
# 1438196562828529671 2021-09-15 13:42:35 -0400 <realDailyWire> Report: NBA Will Not Mandate COVID Vaccine For Players  https://t.co/X61ZRumkZ5  https://t.co/lQeEVtCxh3
# 0  1433500754950623245  1433500754950623245  2021-09-02 14:43:07 EDT
# 1  1433500609030860806  1433500609030860806  2021-09-02 14:42:33 EDT
# 2  1433500436892246016  1433500436892246016  2021-09-02 14:41:51 EDT
# 3  1433498046331949076  1433498046331949076  2021-09-02 14:32:22 EDT
# 4  1433498045509943298  1433498045509943298  2021-09-02 14:32:21 EDT
#
#          date      time  timezone     user_id      username  \
# 0  2021-09-02  14:43:07      -400  3537145515   haluklevent
# 1  2021-09-02  14:42:33      -400    35631695  pabloagustin
# 2  2021-09-02  14:41:51      -400   130496027       jonfavs
# 3  2021-09-02  14:32:22      -400   246621297  georgegammon
# 4  2021-09-02  14:32:21      -400    16129920        maddow
#
#                   name  place  ... geo source user_rt_id user_rt retweet_id  \
# 0         Haluk Levent    NaN  ... NaN    NaN        NaN     NaN        NaN
# 1        Pablo Agustín    NaN  ... NaN    NaN        NaN     NaN        NaN
# 2          Jon Favreau    NaN  ... NaN    NaN        NaN     NaN        NaN
# 3        George Gammon    NaN  ... NaN    NaN        NaN     NaN        NaN
# 4  Rachel Maddow MSNBC    NaN  ... NaN    NaN        NaN     NaN        NaN
#
#    reply_to  retweet_date  translate trans_src trans_dest
# 0        []           NaN        NaN       NaN        NaN
# 1        []           NaN        NaN       NaN        NaN
# 2        []           NaN        NaN       NaN        NaN
# 3        []           NaN        NaN       NaN        NaN
# 4        []           NaN        NaN       NaN        NaN
#
# [5 rows x 36 columns]

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               300 non-null    int64
#  1   conversation_id  300 non-null    int64
#  2   created_at       300 non-null    object
#  3   date             300 non-null    object
#  4   time             300 non-null    object
#  5   timezone         300 non-null    int64
#  6   user_id          300 non-null    int64
#  7   username         300 non-null    object
#  8   name             300 non-null    object
#  9   place            0 non-null      float64
#  10  tweet            300 non-null    object
#  11  language         300 non-null    object
#  12  mentions         300 non-null    object
#  13  urls             300 non-null    object
#  14  photos           300 non-null    object
#  15  replies_count    300 non-null    int64
#  16  retweets_count   300 non-null    int64
#  17  likes_count      300 non-null    int64
#  18  hashtags         300 non-null    object
#  19  cashtags         300 non-null    object
#  20  link             300 non-null    object
#  21  retweet          300 non-null    bool
#  22  quote_url        29 non-null     object
#  23  video            300 non-null    int64
#  24  thumbnail        72 non-null     object
#  25  near             0 non-null      float64
#  26  geo              0 non-null      float64
#  27  source           0 non-null      float64
#  28  user_rt_id       0 non-null      float64
#  29  user_rt          0 non-null      float64
#  30  retweet_id       0 non-null      float64
#  31  reply_to         300 non-null    object
#  32  retweet_date     0 non-null      float64
#  33  translate        0 non-null      float64
#  34  trans_src        0 non-null      float64
#  35  trans_dest       0 non-null      float64
# dtypes: bool(1), float64(11), int64(8), object(16)
# memory usage: 82.4+ KB

# %%
tweets['language']
# Out:
# 0      tr
# 1      es
# 2      en
# 3      en
# 4      en
#        ..
# 295    de
# 296    pt
# 297    en
# 298    pt
# 299    pt
# Name: language, Length: 300, dtype: object

# %% [markdown]
# ## Spotipy
# * Documentation: https://spotipy.readthedocs.io/en/2.16.1/
# * Spotify's API: https://developer.spotify.com/dashboard/applications
# * Additional Spotify datasets: https://research.atspotify.com/datasets/
#
# Don't forget to store your credentials!!

# %%
import config
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(config.spotify['client_id'], 
                                                                         config.spotify['client_secret']))

# %%
playlists = sp.user_playlists('11138449814')['items']
playlist_ids = [p['id'] for p in playlists]
sp.playlist_tracks(playlist_ids[0])['items']
# Out:
# [{'added_at': '2021-04-23T19:22:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2fyOpT5c9kxR8zbDh6UtXh'},
#     'href': 'https://api.spotify.com/v1/albums/2fyOpT5c9kxR8zbDh6UtXh',
#     'id': '2fyOpT5c9kxR8zbDh6UtXh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c6af5ffa661a365b77df6ef6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c6af5ffa661a365b77df6ef6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c6af5ffa661a365b77df6ef6',
#       'width': 64}],
#     'name': 'Save Your Tears (Remix)',
#     'release_date': '2021-04-23',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2fyOpT5c9kxR8zbDh6UtXh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 191013,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12101839'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/37BZB0z9T8Xu7U3e65qxFy'},
#    'href': 'https://api.spotify.com/v1/tracks/37BZB0z9T8Xu7U3e65qxFy',
#    'id': '37BZB0z9T8Xu7U3e65qxFy',
#    'is_local': False,
#    'name': 'Save Your Tears (with Ariana Grande) (Remix)',
#    'popularity': 91,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:37BZB0z9T8Xu7U3e65qxFy'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-23T19:24:24Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Bd1cgCjtCI32PYvDC3ynO'},
#       'href': 'https://api.spotify.com/v1/artists/3Bd1cgCjtCI32PYvDC3ynO',
#       'id': '3Bd1cgCjtCI32PYvDC3ynO',
#       'name': 'London Grammar',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Bd1cgCjtCI32PYvDC3ynO'}],
#     'available_markets': ['AE',
#      'AG',
#      'AO',
#      'BB',
#      'BD',
#      'BF',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BS',
#      'BT',
#      'BW',
#      'CA',
#      'CI',
#      'CM',
#      'CV',
#      'CW',
#      'DJ',
#      'DM',
#      'DO',
#      'DZ',
#      'EG',
#      'FJ',
#      'FM',
#      'GA',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GW',
#      'HK',
#      'HT',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LK',
#      'LR',
#      'LS',
#      'MA',
#      'MG',
#      'MH',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NP',
#      'NR',
#      'OM',
#      'PG',
#      'PH',
#      'PK',
#      'PS',
#      'PW',
#      'QA',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SL',
#      'SN',
#      'ST',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UG',
#      'US',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3wcC3Rowkgk4CffWv84sJH'},
#     'href': 'https://api.spotify.com/v1/albums/3wcC3Rowkgk4CffWv84sJH',
#     'id': '3wcC3Rowkgk4CffWv84sJH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273decc9374b603d2ab6a31491f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02decc9374b603d2ab6a31491f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851decc9374b603d2ab6a31491f',
#       'width': 64}],
#     'name': 'Californian Soil',
#     'release_date': '2021-04-16',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3wcC3Rowkgk4CffWv84sJH'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Bd1cgCjtCI32PYvDC3ynO'},
#      'href': 'https://api.spotify.com/v1/artists/3Bd1cgCjtCI32PYvDC3ynO',
#      'id': '3Bd1cgCjtCI32PYvDC3ynO',
#      'name': 'London Grammar',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Bd1cgCjtCI32PYvDC3ynO'}],
#    'available_markets': ['AE',
#     'AG',
#     'AO',
#     'BB',
#     'BD',
#     'BF',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BS',
#     'BT',
#     'BW',
#     'CA',
#     'CI',
#     'CM',
#     'CV',
#     'CW',
#     'DJ',
#     'DM',
#     'DO',
#     'DZ',
#     'EG',
#     'FJ',
#     'FM',
#     'GA',
#     'GB',
#     'GD',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GW',
#     'HK',
#     'HT',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LK',
#     'LR',
#     'LS',
#     'MA',
#     'MG',
#     'MH',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MU',
#     'MV',
#     'MW',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NP',
#     'NR',
#     'OM',
#     'PG',
#     'PH',
#     'PK',
#     'PS',
#     'PW',
#     'QA',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SG',
#     'SL',
#     'SN',
#     'ST',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UG',
#     'US',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 243284,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBCEN2000071'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2g8y0qpGaM3HTWWJZiInKA'},
#    'href': 'https://api.spotify.com/v1/tracks/2g8y0qpGaM3HTWWJZiInKA',
#    'id': '2g8y0qpGaM3HTWWJZiInKA',
#    'is_local': False,
#    'name': "Baby It's You",
#    'popularity': 49,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ee5f57d85130c86fc7eff544883815b21db4fa3d?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:2g8y0qpGaM3HTWWJZiInKA'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-23T19:28:39Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wugb0kaq0J6nyQ5Xgd17i'},
#       'href': 'https://api.spotify.com/v1/artists/5wugb0kaq0J6nyQ5Xgd17i',
#       'id': '5wugb0kaq0J6nyQ5Xgd17i',
#       'name': 'Aly & AJ',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wugb0kaq0J6nyQ5Xgd17i'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2AMNwptQJMPYkw5p3jjFVc'},
#     'href': 'https://api.spotify.com/v1/albums/2AMNwptQJMPYkw5p3jjFVc',
#     'id': '2AMNwptQJMPYkw5p3jjFVc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731226d2c8f0d17fc7a0f2079e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021226d2c8f0d17fc7a0f2079e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511226d2c8f0d17fc7a0f2079e',
#       'width': 64}],
#     'name': 'Pretty Places',
#     'release_date': '2021-03-05',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2AMNwptQJMPYkw5p3jjFVc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wugb0kaq0J6nyQ5Xgd17i'},
#      'href': 'https://api.spotify.com/v1/artists/5wugb0kaq0J6nyQ5Xgd17i',
#      'id': '5wugb0kaq0J6nyQ5Xgd17i',
#      'name': 'Aly & AJ',
#      'type': 'artist',
#      'uri': 'spotify:artist:5wugb0kaq0J6nyQ5Xgd17i'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 319400,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL2140415'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/465IQvyDIpnizvUbZ8ULyo'},
#    'href': 'https://api.spotify.com/v1/tracks/465IQvyDIpnizvUbZ8ULyo',
#    'id': '465IQvyDIpnizvUbZ8ULyo',
#    'is_local': False,
#    'name': 'Pretty Places',
#    'popularity': 46,
#    'preview_url': 'https://p.scdn.co/mp3-preview/770cc8135e9c736bf511450447cc35b5962f5c3f?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:465IQvyDIpnizvUbZ8ULyo'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-23T19:29:30Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VZn4mB8pS40aE0kujdX2Y'},
#       'href': 'https://api.spotify.com/v1/artists/5VZn4mB8pS40aE0kujdX2Y',
#       'id': '5VZn4mB8pS40aE0kujdX2Y',
#       'name': 'Chloe George',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VZn4mB8pS40aE0kujdX2Y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6W4tUP2tcem0izGTVzxx5g'},
#     'href': 'https://api.spotify.com/v1/albums/6W4tUP2tcem0izGTVzxx5g',
#     'id': '6W4tUP2tcem0izGTVzxx5g',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735b6327459f5454a084d656f0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025b6327459f5454a084d656f0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515b6327459f5454a084d656f0',
#       'width': 64}],
#     'name': 'ghost town (voice memo)',
#     'release_date': '2021-03-30',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6W4tUP2tcem0izGTVzxx5g'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VZn4mB8pS40aE0kujdX2Y'},
#      'href': 'https://api.spotify.com/v1/artists/5VZn4mB8pS40aE0kujdX2Y',
#      'id': '5VZn4mB8pS40aE0kujdX2Y',
#      'name': 'Chloe George',
#      'type': 'artist',
#      'uri': 'spotify:artist:5VZn4mB8pS40aE0kujdX2Y'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 137250,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72104942'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0PKAijroHpnEtdY20bkGdr'},
#    'href': 'https://api.spotify.com/v1/tracks/0PKAijroHpnEtdY20bkGdr',
#    'id': '0PKAijroHpnEtdY20bkGdr',
#    'is_local': False,
#    'name': 'ghost town (voice memo)',
#    'popularity': 71,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0PKAijroHpnEtdY20bkGdr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-23T19:29:34Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#       'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#       'id': '1McMsnEElThX1knmY4oliG',
#       'name': 'Olivia Rodrigo',
#       'type': 'artist',
#       'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#     'available_markets': ['KR'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3lwHyR4joA1xB7Nun21EP6'},
#     'href': 'https://api.spotify.com/v1/albums/3lwHyR4joA1xB7Nun21EP6',
#     'id': '3lwHyR4joA1xB7Nun21EP6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735a61e19eaffec620c1899c47',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025a61e19eaffec620c1899c47',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515a61e19eaffec620c1899c47',
#       'width': 64}],
#     'name': 'deja vu',
#     'release_date': '2021-04-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3lwHyR4joA1xB7Nun21EP6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#    'available_markets': ['KR'],
#    'disc_number': 1,
#    'duration_ms': 215507,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12101240'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/61KpQadow081I2AsbeLcsb'},
#    'href': 'https://api.spotify.com/v1/tracks/61KpQadow081I2AsbeLcsb',
#    'id': '61KpQadow081I2AsbeLcsb',
#    'is_local': False,
#    'name': 'deja vu',
#    'popularity': 62,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:61KpQadow081I2AsbeLcsb'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-23T19:30:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4hDok0OAJd57SGIT8xuWJH'},
#     'href': 'https://api.spotify.com/v1/albums/4hDok0OAJd57SGIT8xuWJH',
#     'id': '4hDok0OAJd57SGIT8xuWJH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a48964b5d9a3d6968ae3e0de',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a48964b5d9a3d6968ae3e0de',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a48964b5d9a3d6968ae3e0de',
#       'width': 64}],
#     'name': "Fearless (Taylor's Version)",
#     'release_date': '2021-04-09',
#     'release_date_precision': 'day',
#     'total_tracks': 26,
#     'type': 'album',
#     'uri': 'spotify:album:4hDok0OAJd57SGIT8xuWJH'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 277591,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12100638'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2CYVETnhM9aytqrazYYwrK'},
#    'href': 'https://api.spotify.com/v1/tracks/2CYVETnhM9aytqrazYYwrK',
#    'id': '2CYVETnhM9aytqrazYYwrK',
#    'is_local': False,
#    'name': 'Mr. Perfectly Fine (Taylor’s Version) (From The Vault)',
#    'popularity': 72,
#    'preview_url': None,
#    'track': True,
#    'track_number': 22,
#    'type': 'track',
#    'uri': 'spotify:track:2CYVETnhM9aytqrazYYwrK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-23T19:34:08Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qRll6DYV06u2VuRPAVqug'},
#       'href': 'https://api.spotify.com/v1/artists/7qRll6DYV06u2VuRPAVqug',
#       'id': '7qRll6DYV06u2VuRPAVqug',
#       'name': 'Foxes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7qRll6DYV06u2VuRPAVqug'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7usouFusikfN2M3B1oVJCm'},
#     'href': 'https://api.spotify.com/v1/albums/7usouFusikfN2M3B1oVJCm',
#     'id': '7usouFusikfN2M3B1oVJCm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cd8713113e91c6ceb2d2f6f6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cd8713113e91c6ceb2d2f6f6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cd8713113e91c6ceb2d2f6f6',
#       'width': 64}],
#     'name': 'Friends In The Corner',
#     'release_date': '2020-09-02',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7usouFusikfN2M3B1oVJCm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qRll6DYV06u2VuRPAVqug'},
#      'href': 'https://api.spotify.com/v1/artists/7qRll6DYV06u2VuRPAVqug',
#      'id': '7qRll6DYV06u2VuRPAVqug',
#      'name': 'Foxes',
#      'type': 'artist',
#      'uri': 'spotify:artist:7qRll6DYV06u2VuRPAVqug'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 209303,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBENL2002765'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4HuwDmSIQOErO4PDvQfJLF'},
#    'href': 'https://api.spotify.com/v1/tracks/4HuwDmSIQOErO4PDvQfJLF',
#    'id': '4HuwDmSIQOErO4PDvQfJLF',
#    'is_local': False,
#    'name': 'Friends In The Corner',
#    'popularity': 39,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cd749cdae69021a3de1048fb6acf224b68616d40?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4HuwDmSIQOErO4PDvQfJLF'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-23T19:34:15Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6P5NO5hzJbuOqSdyPB7SJM'},
#       'href': 'https://api.spotify.com/v1/artists/6P5NO5hzJbuOqSdyPB7SJM',
#       'id': '6P5NO5hzJbuOqSdyPB7SJM',
#       'name': 'Ashe',
#       'type': 'artist',
#       'uri': 'spotify:artist:6P5NO5hzJbuOqSdyPB7SJM'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/37M5pPGs6V1fchFJSgCguX'},
#       'href': 'https://api.spotify.com/v1/artists/37M5pPGs6V1fchFJSgCguX',
#       'id': '37M5pPGs6V1fchFJSgCguX',
#       'name': 'FINNEAS',
#       'type': 'artist',
#       'uri': 'spotify:artist:37M5pPGs6V1fchFJSgCguX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6hjheUnJ3Gp8ll5DuE1VUz'},
#     'href': 'https://api.spotify.com/v1/albums/6hjheUnJ3Gp8ll5DuE1VUz',
#     'id': '6hjheUnJ3Gp8ll5DuE1VUz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739c6c37d0dd4c9ad3b23662fd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029c6c37d0dd4c9ad3b23662fd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519c6c37d0dd4c9ad3b23662fd',
#       'width': 64}],
#     'name': 'Till Forever Falls Apart',
#     'release_date': '2021-03-02',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6hjheUnJ3Gp8ll5DuE1VUz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6P5NO5hzJbuOqSdyPB7SJM'},
#      'href': 'https://api.spotify.com/v1/artists/6P5NO5hzJbuOqSdyPB7SJM',
#      'id': '6P5NO5hzJbuOqSdyPB7SJM',
#      'name': 'Ashe',
#      'type': 'artist',
#      'uri': 'spotify:artist:6P5NO5hzJbuOqSdyPB7SJM'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/37M5pPGs6V1fchFJSgCguX'},
#      'href': 'https://api.spotify.com/v1/artists/37M5pPGs6V1fchFJSgCguX',
#      'id': '37M5pPGs6V1fchFJSgCguX',
#      'name': 'FINNEAS',
#      'type': 'artist',
#      'uri': 'spotify:artist:37M5pPGs6V1fchFJSgCguX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 222860,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USQE92100007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2769RhOZs0ezRncRW1vryp'},
#    'href': 'https://api.spotify.com/v1/tracks/2769RhOZs0ezRncRW1vryp',
#    'id': '2769RhOZs0ezRncRW1vryp',
#    'is_local': False,
#    'name': 'Till Forever Falls Apart',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6741c30dc6c81eef1622a540c1717a7fe5bd37c6?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2769RhOZs0ezRncRW1vryp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-04-23T19:35:39Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MNLhvqJkWsO6tcjY9ps62'},
#       'href': 'https://api.spotify.com/v1/artists/3MNLhvqJkWsO6tcjY9ps62',
#       'id': '3MNLhvqJkWsO6tcjY9ps62',
#       'name': 'Maude Latour',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MNLhvqJkWsO6tcjY9ps62'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0ti1WWYsz8tMMYupwHag7b'},
#     'href': 'https://api.spotify.com/v1/albums/0ti1WWYsz8tMMYupwHag7b',
#     'id': '0ti1WWYsz8tMMYupwHag7b',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273979db397d95c8c368c0334ca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02979db397d95c8c368c0334ca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851979db397d95c8c368c0334ca',
#       'width': 64}],
#     'name': 'Walk Backwards',
#     'release_date': '2021-02-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0ti1WWYsz8tMMYupwHag7b'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MNLhvqJkWsO6tcjY9ps62'},
#      'href': 'https://api.spotify.com/v1/artists/3MNLhvqJkWsO6tcjY9ps62',
#      'id': '3MNLhvqJkWsO6tcjY9ps62',
#      'name': 'Maude Latour',
#      'type': 'artist',
#      'uri': 'spotify:artist:3MNLhvqJkWsO6tcjY9ps62'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 153080,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZN882107583'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4HtwantcVnMCOzGmiyeGmT'},
#    'href': 'https://api.spotify.com/v1/tracks/4HtwantcVnMCOzGmiyeGmT',
#    'id': '4HtwantcVnMCOzGmiyeGmT',
#    'is_local': False,
#    'name': 'Walk Backwards',
#    'popularity': 26,
#    'preview_url': None,
#    'track': True,
# ...
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851779063301154e835a91a35e0',
#       'width': 64}],
#     'name': 'Sob Rock',
#     'release_date': '2021-07-16',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2JmfwvRDitJlTUoLCkp61z'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hEurMDQu99nJRq8pTxO14'},
#      'href': 'https://api.spotify.com/v1/artists/0hEurMDQu99nJRq8pTxO14',
#      'id': '0hEurMDQu99nJRq8pTxO14',
#      'name': 'John Mayer',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hEurMDQu99nJRq8pTxO14'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 249080,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM12101682'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/239yM7BAQ2CkNc61ogPGXo'},
#    'href': 'https://api.spotify.com/v1/tracks/239yM7BAQ2CkNc61ogPGXo',
#    'id': '239yM7BAQ2CkNc61ogPGXo',
#    'is_local': False,
#    'name': 'Shot in the Dark',
#    'popularity': 71,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2f7aebda69b07320700b220cde8b7ee75d8010d1?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:239yM7BAQ2CkNc61ogPGXo'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-23T23:10:30Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hEurMDQu99nJRq8pTxO14'},
#       'href': 'https://api.spotify.com/v1/artists/0hEurMDQu99nJRq8pTxO14',
#       'id': '0hEurMDQu99nJRq8pTxO14',
#       'name': 'John Mayer',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hEurMDQu99nJRq8pTxO14'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2JmfwvRDitJlTUoLCkp61z'},
#     'href': 'https://api.spotify.com/v1/albums/2JmfwvRDitJlTUoLCkp61z',
#     'id': '2JmfwvRDitJlTUoLCkp61z',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273779063301154e835a91a35e0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02779063301154e835a91a35e0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851779063301154e835a91a35e0',
#       'width': 64}],
#     'name': 'Sob Rock',
#     'release_date': '2021-07-16',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2JmfwvRDitJlTUoLCkp61z'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hEurMDQu99nJRq8pTxO14'},
#      'href': 'https://api.spotify.com/v1/artists/0hEurMDQu99nJRq8pTxO14',
#      'id': '0hEurMDQu99nJRq8pTxO14',
#      'name': 'John Mayer',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hEurMDQu99nJRq8pTxO14'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 252413,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM12101681'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4VFGpluBaU1WcquEMzhSz6'},
#    'href': 'https://api.spotify.com/v1/tracks/4VFGpluBaU1WcquEMzhSz6',
#    'id': '4VFGpluBaU1WcquEMzhSz6',
#    'is_local': False,
#    'name': 'Wild Blue',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3b836c140eeb56f60b6f325b2376517b9dd269cb?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:4VFGpluBaU1WcquEMzhSz6'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-28T14:58:28Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11138449814'},
#    'href': 'https://api.spotify.com/v1/users/11138449814',
#    'id': '11138449814',
#    'type': 'user',
#    'uri': 'spotify:user:11138449814'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2eam0iDomRHGBypaDQLwWI'},
#       'href': 'https://api.spotify.com/v1/artists/2eam0iDomRHGBypaDQLwWI',
#       'id': '2eam0iDomRHGBypaDQLwWI',
#       'name': 'Bleachers',
#       'type': 'artist',
#       'uri': 'spotify:artist:2eam0iDomRHGBypaDQLwWI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3h7XkpRVUzecbqOmPVRi2L'},
#     'href': 'https://api.spotify.com/v1/albums/3h7XkpRVUzecbqOmPVRi2L',
#     'id': '3h7XkpRVUzecbqOmPVRi2L',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273585ce9a1312ee594a5b068ac',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02585ce9a1312ee594a5b068ac',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851585ce9a1312ee594a5b068ac',
#       'width': 64}],
#     'name': 'Secret Life (feat. Lana Del Rey)',
#     'release_date': '2021-07-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3h7XkpRVUzecbqOmPVRi2L'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2eam0iDomRHGBypaDQLwWI'},
#      'href': 'https://api.spotify.com/v1/artists/2eam0iDomRHGBypaDQLwWI',
#      'id': '2eam0iDomRHGBypaDQLwWI',
#      'name': 'Bleachers',
#      'type': 'artist',
#      'uri': 'spotify:artist:2eam0iDomRHGBypaDQLwWI'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa'},
#      'href': 'https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa',
#      'id': '00FQb4jTyendYWaN8pK0wa',
#      'name': 'Lana Del Rey',
#      'type': 'artist',
#      'uri': 'spotify:artist:00FQb4jTyendYWaN8pK0wa'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 186613,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC12101250'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2HL0VnhJLtWDZL1UsnLib5'},
#    'href': 'https://api.spotify.com/v1/tracks/2HL0VnhJLtWDZL1UsnLib5',
#    'id': '2HL0VnhJLtWDZL1UsnLib5',
#    'is_local': False,
#    'name': 'Secret Life (feat. Lana Del Rey)',
#    'popularity': 61,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1ab70cfe0fb70eb8efe61f0d346375c3b3199d91?cid=4028dc70439649b08cf6a7c2559fb51c',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2HL0VnhJLtWDZL1UsnLib5'},
#   'video_thumbnail': {'url': None}}]

# %%
def spotipy_search(artist, track):
    query = f'artist: {artist} track: {track}'
    return sp.search(q=query, limit=3)['tracks']['items']

# %%
spotipy_search('dua lipa', 'levitating')
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#      'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#      'id': '6M2wZ9GZgrQXHCFfjv46we',
#      'name': 'Dua Lipa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#      'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#      'id': '4r63FhuTkUYltbVAg5TQnk',
#      'name': 'DaBaby',
#      'type': 'artist',
#      'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/04m06KhJUuwe1Q487puIud'},
#    'href': 'https://api.spotify.com/v1/albums/04m06KhJUuwe1Q487puIud',
#    'id': '04m06KhJUuwe1Q487puIud',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27349caa4fc6f962057ba65576a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0249caa4fc6f962057ba65576a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485149caa4fc6f962057ba65576a',
#      'width': 64}],
#    'name': 'Levitating (feat. DaBaby)',
#    'release_date': '2020-10-01',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:04m06KhJUuwe1Q487puIud'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#     'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#     'id': '6M2wZ9GZgrQXHCFfjv46we',
#     'name': 'Dua Lipa',
#     'type': 'artist',
#     'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#     'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#     'id': '4r63FhuTkUYltbVAg5TQnk',
#     'name': 'DaBaby',
#     'type': 'artist',
#     'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 203064,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHT2000942'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/463CkQjx2Zk1yXoBuierM9'},
#   'href': 'https://api.spotify.com/v1/tracks/463CkQjx2Zk1yXoBuierM9',
#   'id': '463CkQjx2Zk1yXoBuierM9',
#   'is_local': False,
#   'name': 'Levitating (feat. DaBaby)',
#   'popularity': 87,
#   'preview_url': 'https://p.scdn.co/mp3-preview/cc617f669fd1e3ee33a4ac0c66346fefd15286e7?cid=4028dc70439649b08cf6a7c2559fb51c',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:463CkQjx2Zk1yXoBuierM9'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#      'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#      'id': '6M2wZ9GZgrQXHCFfjv46we',
#      'name': 'Dua Lipa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5lKlFlReHOLShQKyRv6AL9'},
#    'href': 'https://api.spotify.com/v1/albums/5lKlFlReHOLShQKyRv6AL9',
#    'id': '5lKlFlReHOLShQKyRv6AL9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d4daf28d55fe4197ede848be',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d4daf28d55fe4197ede848be',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d4daf28d55fe4197ede848be',
#      'width': 64}],
#    'name': 'Future Nostalgia',
#    'release_date': '2020-03-27',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:5lKlFlReHOLShQKyRv6AL9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#     'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#     'id': '6M2wZ9GZgrQXHCFfjv46we',
#     'name': 'Dua Lipa',
#     'type': 'artist',
#     'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#     'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#     'id': '4r63FhuTkUYltbVAg5TQnk',
#     'name': 'DaBaby',
#     'type': 'artist',
#     'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 203064,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHT2000942'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5nujrmhLynf4yMoMtj8AQF'},
#   'href': 'https://api.spotify.com/v1/tracks/5nujrmhLynf4yMoMtj8AQF',
#   'id': '5nujrmhLynf4yMoMtj8AQF',
#   'is_local': False,
#   'name': 'Levitating (feat. DaBaby)',
#   'popularity': 87,
#   'preview_url': 'https://p.scdn.co/mp3-preview/a690735072e85bebf1140d542365751629ae3d74?cid=4028dc70439649b08cf6a7c2559fb51c',
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:5nujrmhLynf4yMoMtj8AQF'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#      'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#      'id': '6M2wZ9GZgrQXHCFfjv46we',
#      'name': 'Dua Lipa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7fJJK56U9fHixgO0HQkhtI'},
#    'href': 'https://api.spotify.com/v1/albums/7fJJK56U9fHixgO0HQkhtI',
#    'id': '7fJJK56U9fHixgO0HQkhtI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273bd26ede1ae69327010d49946',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02bd26ede1ae69327010d49946',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851bd26ede1ae69327010d49946',
#      'width': 64}],
#    'name': 'Future Nostalgia',
#    'release_date': '2020-03-27',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:7fJJK56U9fHixgO0HQkhtI'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#     'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#     'id': '6M2wZ9GZgrQXHCFfjv46we',
#     'name': 'Dua Lipa',
#     'type': 'artist',
#     'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 203807,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHT1901299'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/39LLxExYz6ewLAcYrzQQyP'},
#   'href': 'https://api.spotify.com/v1/tracks/39LLxExYz6ewLAcYrzQQyP',
#   'id': '39LLxExYz6ewLAcYrzQQyP',
#   'is_local': False,
#   'name': 'Levitating',
#   'popularity': 85,
#   'preview_url': 'https://p.scdn.co/mp3-preview/fd22dba2fdce72d699aa81dc298e9dca40ece9e3?cid=4028dc70439649b08cf6a7c2559fb51c',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:39LLxExYz6ewLAcYrzQQyP'}]

# %%
sp.search(q='genre: pop', limit=10)['tracks']['items']
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#      'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#      'id': '7jVv8c5Fj3E9VhNjxT4snq',
#      'name': 'Lil Nas X',
#      'type': 'artist',
#      'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2LIk90788K0zvyj2JJVwkJ'},
#      'href': 'https://api.spotify.com/v1/artists/2LIk90788K0zvyj2JJVwkJ',
#      'id': '2LIk90788K0zvyj2JJVwkJ',
#      'name': 'Jack Harlow',
#      'type': 'artist',
#      'uri': 'spotify:artist:2LIk90788K0zvyj2JJVwkJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/622NFw5Yk0OReMJ2XWcXUh'},
#    'href': 'https://api.spotify.com/v1/albums/622NFw5Yk0OReMJ2XWcXUh',
#    'id': '622NFw5Yk0OReMJ2XWcXUh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ba26678947112dff3c3158bf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ba26678947112dff3c3158bf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ba26678947112dff3c3158bf',
#      'width': 64}],
#    'name': 'INDUSTRY BABY (feat. Jack Harlow)',
#    'release_date': '2021-07-23',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:622NFw5Yk0OReMJ2XWcXUh'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jVv8c5Fj3E9VhNjxT4snq'},
#     'href': 'https://api.spotify.com/v1/artists/7jVv8c5Fj3E9VhNjxT4snq',
#     'id': '7jVv8c5Fj3E9VhNjxT4snq',
#     'name': 'Lil Nas X',
#     'type': 'artist',
#     'uri': 'spotify:artist:7jVv8c5Fj3E9VhNjxT4snq'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2LIk90788K0zvyj2JJVwkJ'},
#     'href': 'https://api.spotify.com/v1/artists/2LIk90788K0zvyj2JJVwkJ',
#     'id': '2LIk90788K0zvyj2JJVwkJ',
#     'name': 'Jack Harlow',
#     'type': 'artist',
#     'uri': 'spotify:artist:2LIk90788K0zvyj2JJVwkJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 212000,
#   'explicit': True,
#   'external_ids': {'isrc': 'USSM12104539'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/27NovPIUIRrOZoCHxABJwK'},
#   'href': 'https://api.spotify.com/v1/tracks/27NovPIUIRrOZoCHxABJwK',
#   'id': '27NovPIUIRrOZoCHxABJwK',
#   'is_local': False,
#   'name': 'INDUSTRY BABY (feat. Jack Harlow)',
#   'popularity': 98,
#   'preview_url': 'https://p.scdn.co/mp3-preview/406f8a854c3a2a3acc957bbb6d6288b26e71874c?cid=4028dc70439649b08cf6a7c2559fb51c',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:27NovPIUIRrOZoCHxABJwK'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#    'href': 'https://api.spotify.com/v1/albums/6s84u2TUpR3wdUv4NgKA2j',
#    'id': '6s84u2TUpR3wdUv4NgKA2j',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a91c10fe9472d9bd89802e5a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a91c10fe9472d9bd89802e5a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a91c10fe9472d9bd89802e5a',
#      'width': 64}],
#    'name': 'SOUR',
#    'release_date': '2021-05-21',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6s84u2TUpR3wdUv4NgKA2j'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#     'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#     'id': '1McMsnEElThX1knmY4oliG',
#     'name': 'Olivia Rodrigo',
#     'type': 'artist',
#     'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 178146,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12101245'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4ZtFanR9U6ndgddUvNcjcG'},
#   'href': 'https://api.spotify.com/v1/tracks/4ZtFanR9U6ndgddUvNcjcG',
#   'id': '4ZtFanR9U6ndgddUvNcjcG',
#   'is_local': False,
#   'name': 'good 4 u',
#   'popularity': 96,
#   'preview_url': None,
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:4ZtFanR9U6ndgddUvNcjcG'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3SpBlxme9WbeQdI9kx7KAV'},
#    'href': 'https://api.spotify.com/v1/albums/3SpBlxme9WbeQdI9kx7KAV',
#    'id': '3SpBlxme9WbeQdI9kx7KAV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736627f8a4e961a92a2fe0d461',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026627f8a4e961a92a2fe0d461',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516627f8a4e961a92a2fe0d461',
#      'width': 64}],
#    'name': 'Certified Lover Boy',
#    'release_date': '2021-09-03',
#    'release_date_precision': 'day',
#    'total_tracks': 21,
#    'type': 'album',
#    'uri': 'spotify:album:3SpBlxme9WbeQdI9kx7KAV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#     'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#     'id': '1RyvyyTE3xzB2ZywiAwp0i',
#     'name': 'Future',
#     'type': 'artist',
#     'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'},
#     'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn',
#     'id': '50co4Is1HCEo8bhOyUWKpn',
#     'name': 'Young Thug',
#     'type': 'artist',
#     'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 257604,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12104403'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0k1WUmIRnG3xU6fvvDVfRG'},
#   'href': 'https://api.spotify.com/v1/tracks/0k1WUmIRnG3xU6fvvDVfRG',
#   'id': '0k1WUmIRnG3xU6fvvDVfRG',
#   'is_local': False,
#   'name': 'Way 2 Sexy (with Future & Young Thug)',
#   'popularity': 91,
#   'preview_url': None,
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:0k1WUmIRnG3xU6fvvDVfRG'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3SpBlxme9WbeQdI9kx7KAV'},
#    'href': 'https://api.spotify.com/v1/albums/3SpBlxme9WbeQdI9kx7KAV',
#    'id': '3SpBlxme9WbeQdI9kx7KAV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736627f8a4e961a92a2fe0d461',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026627f8a4e961a92a2fe0d461',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516627f8a4e961a92a2fe0d461',
#      'width': 64}],
#    'name': 'Certified Lover Boy',
#    'release_date': '2021-09-03',
#    'release_date_precision': 'day',
#    'total_tracks': 21,
#    'type': 'album',
#    'uri': 'spotify:album:3SpBlxme9WbeQdI9kx7KAV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#     'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#     'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#     'name': 'Travis Scott',
#     'type': 'artist',
#     'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 291175,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12104402'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/40iJIUlhi6renaREYGeIDS'},
#   'href': 'https://api.spotify.com/v1/tracks/40iJIUlhi6renaREYGeIDS',
#   'id': '40iJIUlhi6renaREYGeIDS',
#   'is_local': False,
#   'name': 'Fair Trade (with Travis Scott)',
#   'popularity': 92,
#   'preview_url': None,
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:40iJIUlhi6renaREYGeIDS'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3SpBlxme9WbeQdI9kx7KAV'},
#    'href': 'https://api.spotify.com/v1/albums/3SpBlxme9WbeQdI9kx7KAV',
#    'id': '3SpBlxme9WbeQdI9kx7KAV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736627f8a4e961a92a2fe0d461',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026627f8a4e961a92a2fe0d461',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516627f8a4e961a92a2fe0d461',
#      'width': 64}],
#    'name': 'Certified Lover Boy',
#    'release_date': '2021-09-03',
#    'release_date_precision': 'day',
#    'total_tracks': 21,
#    'type': 'album',
#    'uri': 'spotify:album:3SpBlxme9WbeQdI9kx7KAV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#     'href': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK',
#     'id': '5f7VJjfbwm532GiveGC0ZK',
#     'name': 'Lil Baby',
#     'type': 'artist',
#     'uri': 'spotify:artist:5f7VJjfbwm532GiveGC0ZK'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 221979,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12104399'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/37Nqx7iavZpotJSDXZWbJ3'},
#   'href': 'https://api.spotify.com/v1/tracks/37Nqx7iavZpotJSDXZWbJ3',
#   'id': '37Nqx7iavZpotJSDXZWbJ3',
#   'is_local': False,
#   'name': 'Girls Want Girls (with Lil Baby)',
#   'popularity': 91,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:37Nqx7iavZpotJSDXZWbJ3'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/01NhUvviMytvV12pmJiDZH'},
#    'href': 'https://api.spotify.com/v1/albums/01NhUvviMytvV12pmJiDZH',
#    'id': '01NhUvviMytvV12pmJiDZH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273513d821e89b19367f6eb9e62',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02513d821e89b19367f6eb9e62',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851513d821e89b19367f6eb9e62',
#      'width': 64}],
#    'name': 'Bad Habits',
#    'release_date': '2021-06-25',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:01NhUvviMytvV12pmJiDZH'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 231041,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHS2100318'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6PQ88X9TkUIAUIZJHW2upE'},
#   'href': 'https://api.spotify.com/v1/tracks/6PQ88X9TkUIAUIZJHW2upE',
#   'id': '6PQ88X9TkUIAUIZJHW2upE',
#   'is_local': False,
#   'name': 'Bad Habits',
#   'popularity': 97,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0e537207ad0fff8c9e9011735c665d99b9b58d5e?cid=4028dc70439649b08cf6a7c2559fb51c',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:6PQ88X9TkUIAUIZJHW2upE'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#      'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#      'id': '5cj0lLjcoR7YOSnhnX0Po5',
#      'name': 'Doja Cat',
#      'type': 'artist',
#      'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1nAQbHeOWTfQzbOoFrvndW'},
#    'href': 'https://api.spotify.com/v1/albums/1nAQbHeOWTfQzbOoFrvndW',
#    'id': '1nAQbHeOWTfQzbOoFrvndW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734df3245f26298a1579ecc321',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024df3245f26298a1579ecc321',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514df3245f26298a1579ecc321',
#      'width': 64}],
#    'name': 'Planet Her',
#    'release_date': '2021-06-25',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:1nAQbHeOWTfQzbOoFrvndW'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#     'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#     'id': '5cj0lLjcoR7YOSnhnX0Po5',
#     'name': 'Doja Cat',
#     'type': 'artist',
#     'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 210560,
#   'explicit': True,
#   'external_ids': {'isrc': 'USRC12101120'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3Vi5XqYrmQgOYBajMWSvCi'},
#   'href': 'https://api.spotify.com/v1/tracks/3Vi5XqYrmQgOYBajMWSvCi',
#   'id': '3Vi5XqYrmQgOYBajMWSvCi',
#   'is_local': False,
#   'name': 'Need To Know',
#   'popularity': 93,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ed198c528573d97b1ef0c730af1da4f875fc04a4?cid=4028dc70439649b08cf6a7c2559fb51c',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:3Vi5XqYrmQgOYBajMWSvCi'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3SpBlxme9WbeQdI9kx7KAV'},
#    'href': 'https://api.spotify.com/v1/albums/3SpBlxme9WbeQdI9kx7KAV',
#    'id': '3SpBlxme9WbeQdI9kx7KAV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736627f8a4e961a92a2fe0d461',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026627f8a4e961a92a2fe0d461',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516627f8a4e961a92a2fe0d461',
#      'width': 64}],
#    'name': 'Certified Lover Boy',
#    'release_date': '2021-09-03',
#    'release_date_precision': 'day',
#    'total_tracks': 21,
#    'type': 'album',
#    'uri': 'spotify:album:3SpBlxme9WbeQdI9kx7KAV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 336511,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12104397'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2HSmyk2qMN8WQjuGhaQgCk'},
#   'href': 'https://api.spotify.com/v1/tracks/2HSmyk2qMN8WQjuGhaQgCk',
#   'id': '2HSmyk2qMN8WQjuGhaQgCk',
#   'is_local': False,
#   'name': 'Champagne Poetry',
#   'popularity': 89,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2HSmyk2qMN8WQjuGhaQgCk'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3SpBlxme9WbeQdI9kx7KAV'},
#    'href': 'https://api.spotify.com/v1/albums/3SpBlxme9WbeQdI9kx7KAV',
#    'id': '3SpBlxme9WbeQdI9kx7KAV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736627f8a4e961a92a2fe0d461',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026627f8a4e961a92a2fe0d461',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516627f8a4e961a92a2fe0d461',
#      'width': 64}],
#    'name': 'Certified Lover Boy',
#    'release_date': '2021-09-03',
#    'release_date_precision': 'day',
#    'total_tracks': 21,
#    'type': 'album',
#    'uri': 'spotify:album:3SpBlxme9WbeQdI9kx7KAV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 308755,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12104404'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4s7QLoImIwmPi9L6dq1nVW'},
#   'href': 'https://api.spotify.com/v1/tracks/4s7QLoImIwmPi9L6dq1nVW',
#   'id': '4s7QLoImIwmPi9L6dq1nVW',
#   'is_local': False,
#   'name': 'TSU',
#   'popularity': 87,
#   'preview_url': None,
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:4s7QLoImIwmPi9L6dq1nVW'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3SpBlxme9WbeQdI9kx7KAV'},
#    'href': 'https://api.spotify.com/v1/albums/3SpBlxme9WbeQdI9kx7KAV',
#    'id': '3SpBlxme9WbeQdI9kx7KAV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736627f8a4e961a92a2fe0d461',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026627f8a4e961a92a2fe0d461',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516627f8a4e961a92a2fe0d461',
#      'width': 64}],
#    'name': 'Certified Lover Boy',
#    'release_date': '2021-09-03',
#    'release_date_precision': 'day',
#    'total_tracks': 21,
#    'type': 'album',
#    'uri': 'spotify:album:3SpBlxme9WbeQdI9kx7KAV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#     'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#     'id': '1URnnhqYAYcrqrcwql10ft',
#     'name': '21 Savage',
#     'type': 'artist',
#     'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/08Ld63UgKrJ0nZnCkzHtzc'},
#     'href': 'https://api.spotify.com/v1/artists/08Ld63UgKrJ0nZnCkzHtzc',
#     'id': '08Ld63UgKrJ0nZnCkzHtzc',
#     'name': 'Project Pat',
#     'type': 'artist',
#     'uri': 'spotify:artist:08Ld63UgKrJ0nZnCkzHtzc'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 242965,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12104409'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2BcMwX1MPV6ZHP4tUT9uq6'},
#   'href': 'https://api.spotify.com/v1/tracks/2BcMwX1MPV6ZHP4tUT9uq6',
#   'id': '2BcMwX1MPV6ZHP4tUT9uq6',
#   'is_local': False,
#   'name': 'Knife Talk (with 21 Savage ft. Project Pat)',
#   'popularity': 88,
#   'preview_url': None,
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:2BcMwX1MPV6ZHP4tUT9uq6'}]

# %% [markdown]
# ## Reddit
#
# https://praw.readthedocs.io/en/latest/

# %%
import praw

# %%
reddit = praw.Reddit(
    client_id=config.reddit['client_id'],
    client_secret=config.reddit['client_secret'],
    username=config.reddit['username'],
    password=config.reddit['password'],
    user_agent='test'
)

# %%
for submission in reddit.subreddit("learnpython").hot(limit=10):
    print(submission.title)
# Out:
# Ask Anything Monday - Weekly Thread
# How does this function stop calling itself?
# What are the advantages of using classes when doing data analysis?
# How to convert HTML to PDF?
# Where is Corey Schafer?
# Asking about 'None'
# Simple question about __init__
# Flask : how to access data from the html.
# Data extraction from financial statements in PDF format
# Append pandas dataframes?

# %%
list(reddit.subreddit("punpatrol").hot(limit=20))
# Out:
# [Submission(id='9pwt8y'),
#  Submission(id='pohd9u'),
#  Submission(id='popo5d'),
#  Submission(id='poqygd'),
#  Submission(id='pom48z'),
#  Submission(id='pnudyt'),
#  Submission(id='pnf57a'),
#  Submission(id='pnsz8c'),
#  Submission(id='pnm5ln'),
#  Submission(id='pny1hm'),
#  Submission(id='pmtnsf'),
#  Submission(id='pngv2o'),
#  Submission(id='pmdev0'),
#  Submission(id='plzo5o'),
#  Submission(id='pminmi'),
#  Submission(id='pld38k'),
#  Submission(id='pkv119'),
#  Submission(id='plfyny'),
#  Submission(id='pl5ol8'),
#  Submission(id='pkriky')]

# %% [markdown]
# https://praw.readthedocs.io/en/latest/code_overview/models/submission.html

# %%
data = [(sub.id, sub.title, sub.url, sub.score) for sub in reddit.subreddit("news").hot(limit=20)]

# %%
pd.DataFrame(data, columns=['id', 'title', 'url', 'score'])
# Out:
#         id                                              title  \
# 0   posak2  Nicki Minaj said Covid vaccine could make you ...
# 1   popm4j  Hackers steal 'decade's worth of data' from fa...
# 2   pop9tf  World Anti-Doping Agency to review cannabis ba...
# 3   pojloo  Gavin Newsom will remain California governor a...
# 4   porjol  Pfizer says Israel data shows third Covid shot...
# 5   pong52  FBI fires agent accused of failing to properly...
# 6   poq27m  UK court to ensure sexual assault papers can b...
# 7   por2cw  Jupiter just got smacked by a space rock and a...
# 8   poqgrz  GTA public school teacher stripped of license ...
# 9   pouf2m  Simone Biles: FBI turned 'blind eye' to report...
# 10  poqajc  Ancient spider caring for her offspring is tra...
# 11  popq7n  15-year-old girl charged with murder in the de...
# 12  pobhul  U.S. Army says active duty soldiers must be va...
# 13  pokn6t  R. Kelly abused Aaliyah when she was 13 or 14,...
# 14  pobn16  LA officers sue over vaccine mandate as police...
# 15  poemsy  Family of New York woman missing on road trip ...
# 16  po8g7d  Norm Macdonald Dies: Influential Comedian And ...
# 17  ponj7g  Women's ritual baths closed by Jerusalem chief...
# 18  pos60v  Ex-U.S. intel operatives admit hacking America...
# 19  popup0  B.C. mass murderer to apply for release, victi...
#
#                                                   url   score
# 0   https://www.nbcnews.com/news/us-news/nicki-min...    3050
# 1   https://www.jpost.com/diaspora/antisemitism/ha...    4244
# 2   https://news.sky.com/story/world-anti-doping-a...    2549
# 3   https://www.theguardian.com/us-news/2021/sep/1...   59978
# 4   https://www.cnbc.com/2021/09/15/covid-boosters...    1302
# 5   https://www.cnn.com/2021/09/14/politics/larry-...    2406
# 6   https://www.reuters.com/world/uk/uk-court-ensu...    1229
# 7   https://www.space.com/amp/jupiter-impact-flash...     952
# 8   https://www.cbc.ca/news/canada/toronto/gta-tea...     620
# 9   https://apnews.com/article/simone-biles-gymnas...     309
# 10  https://amp.cnn.com/cnn/2021/09/14/world/ancie...     575
# 11  https://apnews.com/article/crime-seattle-hit-a...     582
# 12  https://www.nbcnews.com/politics/politics-news...   22668
# 13  https://www.bbc.com/news/entertainment-arts-58...    1411
# 14  https://www.theguardian.com/us-news/2021/sep/1...    9855
# 15  https://www.nbcnews.com/news/us-news/family-ne...    4720
# 16  https://deadline.com/2021/09/norm-macdonald-de...  107733
# 17  https://www.jpost.com/israel-news/womens-ritua...     546
# 18  https://www.reuters.com/world/us/american-hack...     199
# 19  https://globalnews.ca/news/8191693/bc-mass-mur...     199

# %% [markdown]
# ## Webscraping Boardgames
#
# (And dealing with XML formats)

# %%
import json
import requests
import time
from bs4 import BeautifulSoup

# %%
url = 'https://boardgamegeek.com/xmlapi2/thing?id=3&type=boardgame'
req = requests.get(url).content
soup = BeautifulSoup(req, 'xml')
games = soup.find_all('item')

# %%
games[0]
# Out:
# <item id="3" type="boardgame">
# <thumbnail>https://cf.geekdo-images.com/o9-sNXmFS_TLAb7ZlZ4dRA__thumb/img/22MSUC0-ZWgwzhi_VKIbENJik1w=/fit-in/200x150/filters:strip_icc()/pic3211873.jpg</thumbnail>
# https://cf.geekdo-images.com/o9-sNXmFS_TLAb7ZlZ4dRA__original/img/TPKZgpNxB_C73RNbhKyP6UR76X0=/0x0/filters:format(jpeg)/pic3211873.jpg
# <name sortindex="1" type="primary" value="Samurai"/>
# <name sortindex="1" type="alternate" value="Samouraï"/>
# <name sortindex="1" type="alternate" value="Samurái"/>
# <name sortindex="1" type="alternate" value="Samuraj"/>
# <name sortindex="1" type="alternate" value="Самурай"/>
# <name sortindex="1" type="alternate" value="侍"/>
# <name sortindex="1" type="alternate" value="사무라이"/>
# <description>Samurai is set in medieval Japan. Players compete to gain the favor of three factions: samurai, peasants, and priests, which are represented by helmet, rice paddy, and Buddha figures scattered about the board, which features the islands of Japan. The competition is waged through the use of hexagonal tiles, each of which help curry favor of one of the three factions &amp;mdash; or all three at once! Players can make lightning-quick strikes with horseback ronin and ships or approach their conquests more methodically. As each figure (helmets, rice paddies, and Buddhas) is surrounded, it is awarded to the player who has gained the most favor with the corresponding group.&amp;#10;&amp;#10;Gameplay continues until all the symbols of one type have been removed from the board or four figures have been removed from play due to a tie for influence.&amp;#10;&amp;#10;At the end of the game, players compare captured symbols of each type, competing for majorities in each of the three types. Ties are not uncommon and are broken based on the number of other, &amp;quot;non-majority&amp;quot; symbols each player has collected.&amp;#10;&amp;#10;The game is part of what is sometimes called the Knizia tile-laying trilogy.&amp;#10;&amp;#10;</description>
# <yearpublished value="1998"/>
# <minplayers value="2"/>
# <maxplayers value="4"/>
# <poll name="suggested_numplayers" title="User Suggested Number of Players" totalvotes="313">
# <results numplayers="1">
# <result numvotes="0" value="Best"/>
# <result numvotes="0" value="Recommended"/>
# <result numvotes="149" value="Not Recommended"/>
# </results>
# <results numplayers="2">
# <result numvotes="103" value="Best"/>
# <result numvotes="153" value="Recommended"/>
# <result numvotes="16" value="Not Recommended"/>
# </results>
# <results numplayers="3">
# <result numvotes="179" value="Best"/>
# <result numvotes="93" value="Recommended"/>
# <result numvotes="2" value="Not Recommended"/>
# </results>
# <results numplayers="4">
# <result numvotes="81" value="Best"/>
# <result numvotes="146" value="Recommended"/>
# <result numvotes="27" value="Not Recommended"/>
# </results>
# <results numplayers="4+">
# <result numvotes="0" value="Best"/>
# <result numvotes="1" value="Recommended"/>
# <result numvotes="124" value="Not Recommended"/>
# </results>
# </poll> <playingtime value="60"/>
# <minplaytime value="30"/>
# <maxplaytime value="60"/>
# <minage value="10"/>
# <poll name="suggested_playerage" title="User Suggested Player Age" totalvotes="52">
# <results>
# <result numvotes="0" value="2"/>
# <result numvotes="0" value="3"/>
# <result numvotes="0" value="4"/>
# <result numvotes="0" value="5"/>
# <result numvotes="5" value="6"/>
# <result numvotes="13" value="8"/>
# <result numvotes="29" value="10"/>
# <result numvotes="5" value="12"/>
# <result numvotes="0" value="14"/>
# <result numvotes="0" value="16"/>
# <result numvotes="0" value="18"/>
# <result numvotes="0" value="21 and up"/>
# </results>
# </poll> <poll name="language_dependence" title="Language Dependence" totalvotes="72">
# <results>
# <result level="1" numvotes="72" value="No necessary in-game text"/>
# <result level="2" numvotes="0" value="Some necessary text - easily memorized or small crib sheet"/>
# <result level="3" numvotes="0" value="Moderate in-game text - needs crib sheet or paste ups"/>
# <result level="4" numvotes="0" value="Extensive use of text - massive conversion needed to be playable"/>
# <result level="5" numvotes="0" value="Unplayable in another language"/>
# </results>
# </poll>
# <link id="1009" type="boardgamecategory" value="Abstract Strategy"/>
# <link id="1035" type="boardgamecategory" value="Medieval"/>
# <link id="2080" type="boardgamemechanic" value="Area Majority / Influence"/>
# <link id="2040" type="boardgamemechanic" value="Hand Management"/>
# <link id="2026" type="boardgamemechanic" value="Hexagon Grid"/>
# <link id="2846" type="boardgamemechanic" value="Once-Per-Game Abilities"/>
# <link id="2004" type="boardgamemechanic" value="Set Collection"/>
# <link id="2002" type="boardgamemechanic" value="Tile Placement"/>
# <link id="10634" type="boardgamefamily" value="Country: Japan"/>
# <link id="70711" type="boardgamefamily" value="Digital Implementations: Triqqy"/>
# <link id="60111" type="boardgamefamily" value="Series: Euro Classics (Reiner Knizia)"/>
# <link id="42" type="boardgamefamily" value="Series: Tile-Laying Trilogy (Reiner Knizia)"/>
# <link id="28732" type="boardgamefamily" value="Theme: Samurai"/>
# <link id="35634" type="boardgameimplementation" value="Samurai: The Card Game"/>
# <link id="2" type="boardgamedesigner" value="Reiner Knizia"/>
# <link id="11883" type="boardgameartist" value="Franz Vohwinkel"/>
# <link id="17" type="boardgamepublisher" value="Fantasy Flight Games"/>
# <link id="133" type="boardgamepublisher" value="Hans im Glück"/>
# <link id="267" type="boardgamepublisher" value="999 Games"/>
# <link id="29" type="boardgamepublisher" value="ABACUSSPIELE"/>
# <link id="7340" type="boardgamepublisher" value="Astrel Games"/>
# <link id="7335" type="boardgamepublisher" value="Ceilikan Jogos"/>
# <link id="41" type="boardgamepublisher" value="Descartes Editeur"/>
# <link id="2973" type="boardgamepublisher" value="Edge Entertainment"/>
# <link id="4617" type="boardgamepublisher" value="Galakta"/>
# <link id="1391" type="boardgamepublisher" value="Hobby Japan"/>
# <link id="8291" type="boardgamepublisher" value="Korea Boardgames Co., Ltd."/>
# <link id="5812" type="boardgamepublisher" value="Lacerta"/>
# <link id="3218" type="boardgamepublisher" value="Lautapelit.fi"/>
# <link id="3" type="boardgamepublisher" value="Rio Grande Games"/>
# <link id="3954" type="boardgamepublisher" value="Skandinavisk  Spil Kompagni"/>
# <link id="8313" type="boardgamepublisher" value="Smart Ltd"/>
# <link id="8759" type="boardgamepublisher" value="Wargames Club Publishing"/>
# </item>

# %%
names = games[0].find_all('name')
names
# Out:
# [<name sortindex="1" type="primary" value="Samurai"/>,
#  <name sortindex="1" type="alternate" value="Samouraï"/>,
#  <name sortindex="1" type="alternate" value="Samurái"/>,
#  <name sortindex="1" type="alternate" value="Samuraj"/>,
#  <name sortindex="1" type="alternate" value="Самурай"/>,
#  <name sortindex="1" type="alternate" value="侍"/>,
#  <name sortindex="1" type="alternate" value="사무라이"/>]

# %%
names[5]['value']
# Out:
# '侍'

# %%
games[0].find_all('name')[0]['type']
# Out:
# 'primary'

# %%
name = list(filter(lambda n: n['type'] == "primary", names))

# %%
name
# Out:
# [<name sortindex="1" type="primary" value="Samurai"/>]

# %%
name[0]['value']
# Out:
# 'Samurai'

# %%
games[0].find('description').text
# Out:
# 'Samurai is set in medieval Japan. Players compete to gain the favor of three factions: samurai, peasants, and priests, which are represented by helmet, rice paddy, and Buddha figures scattered about the board, which features the islands of Japan. The competition is waged through the use of hexagonal tiles, each of which help curry favor of one of the three factions &mdash; or all three at once! Players can make lightning-quick strikes with horseback ronin and ships or approach their conquests more methodically. As each figure (helmets, rice paddies, and Buddhas) is surrounded, it is awarded to the player who has gained the most favor with the corresponding group.&#10;&#10;Gameplay continues until all the symbols of one type have been removed from the board or four figures have been removed from play due to a tie for influence.&#10;&#10;At the end of the game, players compare captured symbols of each type, competing for majorities in each of the three types. Ties are not uncommon and are broken based on the number of other, &quot;non-majority&quot; symbols each player has collected.&#10;&#10;The game is part of what is sometimes called the Knizia tile-laying trilogy.&#10;&#10;'

# %%
games[0].find('description').text
# Out:
# 'Samurai is set in medieval Japan. Players compete to gain the favor of three factions: samurai, peasants, and priests, which are represented by helmet, rice paddy, and Buddha figures scattered about the board, which features the islands of Japan. The competition is waged through the use of hexagonal tiles, each of which help curry favor of one of the three factions &mdash; or all three at once! Players can make lightning-quick strikes with horseback ronin and ships or approach their conquests more methodically. As each figure (helmets, rice paddies, and Buddhas) is surrounded, it is awarded to the player who has gained the most favor with the corresponding group.&#10;&#10;Gameplay continues until all the symbols of one type have been removed from the board or four figures have been removed from play due to a tie for influence.&#10;&#10;At the end of the game, players compare captured symbols of each type, competing for majorities in each of the three types. Ties are not uncommon and are broken based on the number of other, &quot;non-majority&quot; symbols each player has collected.&#10;&#10;The game is part of what is sometimes called the Knizia tile-laying trilogy.&#10;&#10;'

# %% [markdown]
# ## Scraping Craigslist
#
# https://newyork.craigslist.org/search/aap

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = 'https://newyork.craigslist.org/search/hhh?'
soup = BeautifulSoup(requests.get(url).text)

# getting each apartment's html as an element in a list

apartments =  soup.findAll('li', {'class':"result-row"})

# %%
apartments[0]
# Out:
# <li class="result-row" data-pid="7380739077">
# <a class="result-image gallery" data-ids="3:00p0p_52lIOhmm5FOz_0CI0pO,3:00l0l_7Wrlfnq9HjRz_0CI0pO,3:00e0e_lkY3yzhZJeiz_0CI0pO,3:00t0t_aFFlI1Baakqz_0CI0pO,3:00000_aQxpVzG6ouHz_0CI0pO,3:00D0D_esqEOTg6dTDz_0CI0pO,3:00101_lnob8TCnNPyz_0CI0pO,3:00d0d_d9XV4aiGQpFz_0CI0pO" href="https://newyork.craigslist.org/que/apa/d/astoria-no-fee-beautiful-one-bedroom/7380739077.html">
# <span class="result-price">$1,800</span>
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-09-15 14:17" title="Wed 15 Sep 02:17:17 PM">Sep 15</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7380739077" href="https://newyork.craigslist.org/que/apa/d/astoria-no-fee-beautiful-one-bedroom/7380739077.html" id="postid_7380739077">NO FEE! BEAUTIFUL ONE BEDROOM APT- ASTORIA/WOODSIDE BORDER</a>
# </h3>
# <span class="result-meta">
# <span class="result-price">$1,800</span>
# <span class="housing">
#                     1br -
#                 </span>
# <span class="result-hood"> (Astoria/Woodside queens )</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>

# %%
soup.findAll('li', {'class':"result-row"})[0]
# Out:
# <li class="result-row" data-pid="7380739077">
# <a class="result-image gallery" data-ids="3:00p0p_52lIOhmm5FOz_0CI0pO,3:00l0l_7Wrlfnq9HjRz_0CI0pO,3:00e0e_lkY3yzhZJeiz_0CI0pO,3:00t0t_aFFlI1Baakqz_0CI0pO,3:00000_aQxpVzG6ouHz_0CI0pO,3:00D0D_esqEOTg6dTDz_0CI0pO,3:00101_lnob8TCnNPyz_0CI0pO,3:00d0d_d9XV4aiGQpFz_0CI0pO" href="https://newyork.craigslist.org/que/apa/d/astoria-no-fee-beautiful-one-bedroom/7380739077.html">
# <span class="result-price">$1,800</span>
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-09-15 14:17" title="Wed 15 Sep 02:17:17 PM">Sep 15</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7380739077" href="https://newyork.craigslist.org/que/apa/d/astoria-no-fee-beautiful-one-bedroom/7380739077.html" id="postid_7380739077">NO FEE! BEAUTIFUL ONE BEDROOM APT- ASTORIA/WOODSIDE BORDER</a>
# </h3>
# <span class="result-meta">
# <span class="result-price">$1,800</span>
# <span class="housing">
#                     1br -
#                 </span>
# <span class="result-hood"> (Astoria/Woodside queens )</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>

# %%
apartments[0]

# %%
titles = [a.find('a', {'class': 'result-title hdrlnk'}).text for a in apartments]
prices = [a.find('span', {'class': 'result-price'}) for a in apartments]

# %%
len(titles)
# Out:
# 120

# %%
len(prices)
# Out:
# 120

# %%
# getting attributes via list comprehension
prices = []
hoods = []
for a in apartments:
    result = a.find('span', {'class': 'result-hood'})
    price = a.find('span', {'class': 'result-price'})
    if result == None:
        hoods.append(None)
        prices.append(None)
    else:
        hoods.append(result.text)
        prices.append(price)

# for 'hoods', some are NoneType

# putting it in a dataframe:

df = pd.DataFrame(columns = ['titles', 'prices', 'hoods'])
df['titles'] = titles
df['prices'] = prices
df['hoods'] = hoods

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   titles  120 non-null    object
#  1   prices  118 non-null    object
#  2   hoods   120 non-null    object
# dtypes: object(3)
# memory usage: 2.9+ KB

# %% [markdown]
# ## Additional Things to Explore
#
# * BeautifulSoup not finding the exact info you're trying to scrape? Try **Selenium**
#     * https://www.scrapingbee.com/blog/selenium-python/
#
# * ScraPy is another library (newer) used for scraping
#     * https://scrapy.org/
